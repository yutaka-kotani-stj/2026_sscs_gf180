# %% [markdown]
# # GF180MCUD Vgs sweep

# %% [markdown]
# # Preparation

# %%
# %%writefile .spiceinit
# set ngbehavior=hs
# Out:
# Overwriting .spiceinit

# %% [markdown]
# # PMOS simulation

# %% [markdown]
# ## Create NGSPICE netlist

# %%
# %%writefile pmos_netlist.spice
# * PMOS VGS sweep
# * Please Modify include and lib path according to your enviroment.
# .include "/foss/pdks/gf180mcuD/libs.tech/ngspice/design.ngspice"
# .lib "/foss/pdks/gf180mcuD/libs.tech/ngspice/sm141064.ngspice" typical
#
# * MOS parameter
# .param mos_l=0.28u
# .param mos_w=1u
# .param mos_nf=ceil(1)
# .param mos_m=ceil(1)
# .param mos_ad={ceil((mos_nf+1)/2)*mos_w/mos_nf*0.18u}
# .param mos_as={ceil((mos_nf+2)/2)*mos_w/mos_nf*0.18u}
# .param mos_pd={2*ceil((mos_nf+1)/2)*(mos_w/mos_nf+0.18u)}
# .param mos_ps={2*ceil((mos_nf+2)/2)*(mos_w/mos_nf+0.18u)}
# .param mos_nrd={0.18u/mos_w}
# .param mos_nrs={0.18u/mos_w}
# .param mos_sa=0
# .param mos_sb=0
# .param mos_sd=0
# XM1 D G S B pfet_03v3 L=mos_l W=mos_w  nf=mos_nf ad=mos_ad as=mos_as pd=mos_pd ps=mos_ps nrd=mos_nrd nrs=mos_nrs sa=mos_sa sb=mos_sb sd=mos_sd m=mos_m
# vg 0 g dc 1 ac 1
# vd 0 d 3.3
# vs 0 s 0
# vb 0 b 0
# .op
# .option post nomod
# .end
# .control
# option savecurrents
# save all
# * DC alanysis to obtain id vs Vgs
# dc vg 0 3.3 0.001
# display
# set wr_vecnames               ; for wrdata: write the vector names
# wrdata pmos_output_dc.txt i(vd)
#
# * AC analysis from 1Hz to 1GHz to obtain Cgg
# ac dec 10 1 1G
# let cgg = imag(i(vg)) / (2 * pi * frequency)
# set wr_vecnames               ; for wrdata: write the vector names
# wrdata pmos_output_ac.txt cgg
#
# .endc
# Out:
# Writing pmos_netlist.spice

# %% [markdown]
# ## Execute NGSPICE simulation

# %%
# !ngspice -b pmos_netlist.spice
# Out:
# Note: No compatibility mode selected!
#
#
# Circuit: * pmos vgs sweep
#
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#  Reference value :  1.85900e+00
# No. of Data Rows : 3301
# Here are the vectors currently active:
#
# Title: * pmos vgs sweep
# Name: dc1 (DC transfer characteristic)
# Date: Sat May  2 04:48:30  2026
#
#     b                   : voltage, real, 3301 long
#     d                   : voltage, real, 3301 long
#     g                   : voltage, real, 3301 long
#     s                   : voltage, real, 3301 long
#     v-sweep             : voltage, real, 3301 long [default scale]
#     vb#branch           : current, real, 3301 long
#     vd#branch           : current, real, 3301 long
#     vg#branch           : current, real, 3301 long
#     vs#branch           : current, real, 3301 long
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#
# No. of Data Rows : 91
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#  Reference value :  0.00000e+00
# No. of Data Rows : 1
# 	Node                                  Voltage
# 	----                                  -------
# 	----	-------
# 	b                                0.000000e+00
# 	s                                0.000000e+00
# 	g                                -1.00000e+00
# 	d                                -3.30000e+00
#
# 	Source	Current
# 	------	-------
#
# 	vg#branch                        0.000000e+00
# 	vd#branch                        -9.00053e-06
# 	vs#branch                        8.992467e-06
# 	vb#branch                        8.063973e-09
#
#  BSIM4v5: Berkeley Short Channel IGFET Model-4
#      device              m.xm1.m0
#       model           pfet_03v3.4
#           l               2.8e-07
#           w                 1e-06
#           m                     1
#          nf                     1
#          sa                     0
#          sb                     0
#          sd                     0
#         sca                     0
#         scb                     0
#         scc                     0
#          sc                     0
#         min                     0
#          ad               1.8e-13
#          as               3.6e-13
#          pd              2.36e-06
#          ps              4.72e-06
#         nrd                  0.18
#         nrs                  0.18
#         off                     0
#        rbdb                    50
#        rbsb                    50
#        rbpb                    50
#        rbps                    50
#        rbpd                    50
#      delvto                    -0
#       mulu0                     1
#         xgw                     0
#       ngcon                     1
#    trnqsmod                     0
#    acnqsmod                     0
#    rbodymod                     0
#    rgatemod                     0
#      geomod                     0
#     rgeomod                     0
#        gmbs           1.50478e-05
#          gm           4.76979e-05
#         gds           9.71812e-07
#       vdsat              0.323871
#         vth              0.681217
#          id           8.99247e-06
#         ibd          -3.30293e-12
#         ibs          -1.13321e-17
#         gbd           1.00327e-12
#         gbs           1.00014e-12
#        isub           8.06067e-09
#       igidl           3.80732e-16
#       igisl                     0
#         igs                     0
#         igd                     0
#         igb                     0
#        igcs                     0
#        igcd                     0
#         vbs          -1.13305e-05
#         vgs              0.999989
#         vds               3.29998
#         cgg           9.35907e-16
#         cgs          -7.03371e-16
#         cgd           6.20628e-18
#         cbg          -1.58225e-16
#         cbd           2.96245e-18
#         cbs          -3.23007e-16
#         cdg          -3.11088e-16
#         cdd          -3.66369e-18
#         cds           4.10569e-16
#         csg          -4.66594e-16
#         csd          -5.50504e-18
#         css           6.15809e-16
#         cgb          -2.38743e-16
#         cdb          -9.58167e-17
#         csb          -1.43711e-16
#         cbb            4.7827e-16
#       capbd           6.09253e-16
#       capbs           1.38222e-15
#          qg           1.31245e-15
#          qb          -9.52353e-16
#          qd          -1.44044e-16
#          qs          -2.16051e-16
#        qinv           2.59186e-16
#        qdef                    -0
#        gcrg                     0
#        gtau                     0
#     vgsteff               0.31864
#      vdseff              0.322787
#        cgso           1.63957e-16
#        cgdo           1.34035e-16
#        cgbo              2.96e-20
#        weff              1.02e-06
#        leff               2.8e-07
#
#  Vsource: Independent voltage source
#      device                    vb                    vs                    vd
#          dc                     0                     0                   3.3
#       acmag                     0                     0                     0
#       pulse         -         -         -
#         sin         -         -         -
#         exp         -         -         -
#         pwl         -         -         -
#        sffm         -         -         -
#          am         -         -         -
#     trnoise         -         -         -
#    trrandom         -         -         -
#     portnum                     0                     0                     0
#          z0                     0                     0                     0
#         pwr                     0                     0                     0
#        freq                     0                     0                     0
#       phase                     0                     0                     0
#           i           8.06397e-09           8.99247e-06          -9.00053e-06
#           p                     0                     0          -2.97018e-05
#
#  Vsource: Independent voltage source
#      device                    vg
#          dc                     1
#       acmag                     1
#       pulse         -
#         sin         -
#         exp         -
#         pwl         -
#        sffm         -
#          am         -
#     trnoise         -
#    trrandom         -
#     portnum                     0
#          z0                     0
#         pwr                     0
#        freq                     0
#       phase                     0
#           i                     0
#           p                     0
#
#
# Total analysis time (seconds) = 0.0529253
#
# Total elapsed time (seconds) = 0.135
#
# Total DRAM available = 15374.188 MB.
# DRAM currently available = 10370.090 MB.
# Maximum ngspice program size =   87.512 MB.
# Current ngspice program size =   19.250 MB.
#
# Shared ngspice pages =   11.125 MB.
# Text (code) pages =    5.918 MB.
# Stack = 0 bytes.
# Library pages =   64.098 MB.

# %% [markdown]
# ## Visualize PMOS characteristics

# %% [markdown]
# ## Load PMOS simulation result

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pmos_w=1e-6
pmos_df = pd.read_csv("pmos_output_dc.txt", delim_whitespace=True, header=0)
pmos_df.columns = ["vgs", "id"]
pmos_df['id'] = pmos_df['id']*-1
pmos_df['gm'] = np.gradient(pmos_df['id'])/np.gradient(pmos_df['vgs']);
pmos_df['gm_id'] = pmos_df['gm']/pmos_df['id']

pmos_ac_df = pd.read_csv("pmos_output_ac.txt", delim_whitespace=True, header=0)
pmos_ac_df.columns = ["frequency", "cgg", "cgg2"]
pmos_cgg = pmos_ac_df["cgg"][0]*-1

pmos_df['f_T'] = pmos_df['gm']/pmos_cgg/2/math.pi
pmos_df['id_w'] = pmos_df['id']/pmos_w
pmos_df['f_T_gm_id'] = pmos_df['f_T']*pmos_df['gm_id']
# Out:
# /tmp/ipykernel_25188/4065248307.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pmos_df = pd.read_csv("pmos_output_dc.txt", delim_whitespace=True, header=0)
# /tmp/ipykernel_25188/4065248307.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pmos_ac_df = pd.read_csv("pmos_output_ac.txt", delim_whitespace=True, header=0)

# %% [markdown]
# ## Plot -Vgs vs -id

# %%
pmos_df.plot(x="vgs", y="id", grid=True,legend=False)
plt.title("-id vs -Vgs")
plt.ylabel("-id [A]")
plt.xlabel("-Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot gm vs Vgs

# %%
pmos_df.plot(x="vgs", y="gm", grid=True,legend=False)
plt.title("gm vs Vgs")
plt.ylabel("gm [S]")
plt.xlabel("Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot id/w vs gm/id

# %%
pmos_df.plot(x="gm_id", y="id_w",logy=True, grid=True,legend=False)
plt.title("id/w vs gm/id")
plt.ylim(1e-1,10)
plt.xlim(1e-1,25)

plt.ylabel("id/w [A/m]")
plt.xlabel("gm/id [S/A]")
plt.show()

# %% [markdown]
# ## Calculate W from id and gm

# %%
# Returns interpolated Y for a given X_value using df columns
from scipy import interpolate
f_pmos_gm_id_to_id_w = interpolate.interp1d(pmos_df['gm_id'], pmos_df['id_w'])

#define design parameter
pmos_l = 0.28e-6
pmos_id = 1e-6
pmos_gm = 10e-6
pmos_gm_id=pmos_gm/pmos_id
pmos_id_w = f_pmos_gm_id_to_id_w(pmos_gm_id)
pmos_w = pmos_id/pmos_id_w
print(f"pmos_id: {pmos_id}")
print(f"pmos_gm: {pmos_gm}")
print(f"pmos_l: {pmos_l}")
print(f"pmos_w: {pmos_w}")
# Out:
# pmos_id: 1e-06
# pmos_gm: 1e-05
# pmos_l: 2.8e-07
# pmos_w: 3.8629249597739036e-07

# %% [markdown]
# ## Plot -Vgs vs -gm/id

# %%
pmos_df.plot(x="vgs", y="gm_id", grid=True,legend=False)
plt.title("-gm/id vs -Vgs")
plt.ylabel("-gm/id [S/A]")
plt.xlabel("-Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot -Vgs vs f_T

# %%
pmos_df.plot(x="vgs", y="f_T", grid=True,legend=False)
plt.title("f_T vs -Vgs")
plt.ylabel("f_T [Hz]")
plt.xlabel("-Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot f_T*gm/id vs gm/id

# %%
pmos_df.plot(x="gm_id", y="f_T_gm_id", grid=True,legend=False)
plt.title("f_T*gm/id vs gm/id")
plt.ylabel("f_T*gm/id [Hz*S/A]")
plt.xlabel("gm/id [S/A]")
plt.xlim(1e-1,20)
plt.ylim(1e-1,4e10)
plt.show()
pmos_max_index=np.argmax(pmos_df['f_T_gm_id'])
pmos_gm_id_on_max_f_T_gm_id = pmos_df['gm_id'][pmos_max_index]
pmos_max_f_T_gm_id = pmos_df['f_T_gm_id'][pmos_max_index]
print('max')
print(f'f_T*gm/id:{pmos_max_f_T_gm_id}')
print(f'gm/id:{pmos_gm_id_on_max_f_T_gm_id}')
# Out:
# max
# f_T*gm/id:34596027810.62444
# gm/id:7.885356565251122

# %% [markdown]
# ## Calculate W and id from gm on Max f_T*gm/id

# %%
#define design parameter
pmos_gm=100e-6
pmos_gm_id=pmos_gm_id_on_max_f_T_gm_id
pmos_id=pmos_gm/pmos_gm_id 
pmos_id_w = f_pmos_gm_id_to_id_w(pmos_gm_id)
pmos_w = pmos_id/pmos_id_w
print(f"pmos_gm: {pmos_gm}")
print(f"pmos_id: {pmos_id}")
print(f"pmos_gm_id: {pmos_gm_id}")
print(f"pmos_l: {pmos_l}")
print(f"pmos_w: {pmos_w}")
# Out:
# pmos_gm: 0.0001
# pmos_id: 1.2681734703117429e-05
# pmos_gm_id: 7.885356565251122
# pmos_l: 2.8e-07
# pmos_w: 2.939955524352831e-06

# %% [markdown]
# # NMOS simulation

# %% [markdown]
# ## Create NGSPICE netlist

# %%
# %%writefile nmos_netlist.spice
# * NMOS VGS sweep
# * Please Modify include and lib path according to your enviroment.
# .include "/foss/pdks/gf180mcuD/libs.tech/ngspice/design.ngspice"
# .lib "/foss/pdks/gf180mcuD/libs.tech/ngspice/sm141064.ngspice" typical
#
# * MOS parameter
# .param mos_l=0.28u
# .param mos_w=1u
# .param mos_nf=ceil(1)
# .param mos_m=ceil(1)
# .param mos_ad={ceil((mos_nf+1)/2)*mos_w/mos_nf*0.18u}
# .param mos_as={ceil((mos_nf+2)/2)*mos_w/mos_nf*0.18u}
# .param mos_pd={2*ceil((mos_nf+1)/2)*(mos_w/mos_nf+0.18u)}
# .param mos_ps={2*ceil((mos_nf+2)/2)*(mos_w/mos_nf+0.18u)}
# .param mos_nrd={0.18u/mos_w}
# .param mos_nrs={0.18u/mos_w}
# .param mos_sa=0
# .param mos_sb=0
# .param mos_sd=0
# XM1 D G S B nfet_03v3 L=mos_l W=mos_w  nf=mos_nf ad=mos_ad as=mos_as pd=mos_pd ps=mos_ps nrd=mos_nrd nrs=mos_nrs sa=mos_sa sb=mos_sb sd=mos_sd m=mos_m
# vg g 0 dc 1 ac 1
# vd d 0 3.3
# vs s 0 0
# vb b 0 0
# .op
# .option post nomod
# .end
# .control
# * DC alanysis to obtain id vs Vgs
# dc vg 0 3.3 0.001
# display
# set wr_vecnames               ; for wrdata: write the vector names
# wrdata nmos_output_dc.txt i(vd)
#
# * AC analysis from 1Hz to 1GHz to obtain Cgg
# ac dec 10 1 1G
# let cgg = imag(i(vg)) / (2 * pi * frequency)
# set wr_vecnames               ; for wrdata: write the vector names
# wrdata nmos_output_ac.txt cgg
# .endc
# Out:
# Overwriting nmos_netlist.spice

# %% [markdown]
# ## Execute NGSPICE simulation

# %%
# !ngspice -b nmos_netlist.spice
# Out:
# Note: No compatibility mode selected!
#
#
# Circuit: * nmos vgs sweep
#
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#  Reference value :  1.67300e+00
# No. of Data Rows : 3301
# Here are the vectors currently active:
#
# Title: * nmos vgs sweep
# Name: dc1 (DC transfer characteristic)
# Date: Sat May  2 04:50:31  2026
#
#     b                   : voltage, real, 3301 long
#     d                   : voltage, real, 3301 long
#     g                   : voltage, real, 3301 long
#     s                   : voltage, real, 3301 long
#     v-sweep             : voltage, real, 3301 long [default scale]
#     vb#branch           : current, real, 3301 long
#     vd#branch           : current, real, 3301 long
#     vg#branch           : current, real, 3301 long
#     vs#branch           : current, real, 3301 long
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#  Reference value :  1.00000e+00
# No. of Data Rows : 91
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#
# No. of Data Rows : 1
# 	Node                                  Voltage
# 	----                                  -------
# 	----	-------
# 	b                                0.000000e+00
# 	s                                0.000000e+00
# 	g                                1.000000e+00
# 	d                                3.300000e+00
#
# 	Source	Current
# 	------	-------
#
# 	vg#branch                        0.000000e+00
# 	vd#branch                        -4.51295e-05
# 	vs#branch                        4.443090e-05
# 	vb#branch                        6.985782e-07
#
#  BSIM4v5: Berkeley Short Channel IGFET Model-4
#      device              m.xm1.m0
#       model           nfet_03v3.4
#           l               2.8e-07
#           w                 1e-06
#           m                     1
#          nf                     1
#          sa                     0
#          sb                     0
#          sd                     0
#         sca                     0
#         scb                     0
#         scc                     0
#          sc                     0
#         min                     0
#          ad               1.8e-13
#          as               3.6e-13
#          pd              2.36e-06
#          ps              4.72e-06
#         nrd                  0.18
#         nrs                  0.18
#         off                     0
#        rbdb                    50
#        rbsb                    50
#        rbpb                    50
#        rbps                    50
#        rbpd                    50
#      delvto                    -0
#       mulu0                     1
#         xgw                     0
#       ngcon                     1
#    trnqsmod                     0
#    acnqsmod                     0
#    rbodymod                     0
#    rgatemod                     0
#      geomod                     0
#     rgeomod                     0
#        gmbs            3.2098e-05
#          gm           0.000155443
#         gds           6.08356e-06
#       vdsat              0.341659
#         vth              0.589748
#          id           4.44309e-05
#         ibd          -3.29994e-12
#         ibs          -5.59855e-17
#         gbd                 1e-12
#         gbs           1.00005e-12
#        isub           6.98575e-07
#       igidl           6.58118e-22
#       igisl                     0
#         igs                     0
#         igd                     0
#         igb                     0
#        igcs                     0
#        igcd                     0
#         vbs          -5.59829e-05
#         vgs              0.999944
#         vds               3.29989
#         cgg           8.47042e-16
#         cgs           -7.0388e-16
#         cgd           1.25943e-17
#         cbg          -1.33113e-16
#         cbd              2.91e-18
#         cbs          -1.65318e-16
#         cdg          -2.85585e-16
#         cdd          -6.19909e-18
#         cds           3.47693e-16
#         csg          -4.28344e-16
#         csd          -9.30522e-18
#         css           5.21505e-16
#         cgb          -1.55757e-16
#         cdb          -5.59087e-17
#         csb          -8.38559e-17
#         cbb           2.95521e-16
#       capbd           6.29806e-16
#       capbs            1.5327e-15
#          qg           9.28842e-16
#          qb          -6.53204e-16
#          qd           -1.1026e-16
#          qs          -1.65378e-16
#        qinv           3.13482e-16
#        qdef                     0
#        gcrg                     0
#        gtau                     0
#     vgsteff              0.401668
#      vdseff              0.339937
#        cgso           1.99893e-16
#        cgdo           1.25087e-16
#        cgbo               2.8e-20
#        weff               9.8e-07
#        leff               2.8e-07
#
#  Vsource: Independent voltage source
#      device                    vb                    vs                    vd
#          dc                     0                     0                   3.3
#       acmag                     0                     0                     0
#       pulse         -         -         -
#         sin         -         -         -
#         exp         -         -         -
#         pwl         -         -         -
#        sffm         -         -         -
#          am         -         -         -
#     trnoise         -         -         -
#    trrandom         -         -         -
#     portnum                     0                     0                     0
#          z0                     0                     0                     0
#         pwr                     0                     0                     0
#        freq                     0                     0                     0
#       phase                     0                     0                     0
#           i           6.98578e-07           4.44309e-05          -4.51295e-05
#           p                     0                     0          -0.000148927
#
#  Vsource: Independent voltage source
#      device                    vg
#          dc                     1
#       acmag                     1
#       pulse         -
#         sin         -
#         exp         -
#         pwl         -
#        sffm         -
#          am         -
#     trnoise         -
#    trrandom         -
#     portnum                     0
#          z0                     0
#         pwr                     0
#        freq                     0
#       phase                     0
#           i                     0
#           p                     0
#
#
# Total analysis time (seconds) = 0.0552322
#
# Total elapsed time (seconds) = 0.133
#
# Total DRAM available = 15374.188 MB.
# DRAM currently available = 10280.238 MB.
# Maximum ngspice program size =   87.512 MB.
# Current ngspice program size =   19.375 MB.
#
# Shared ngspice pages =   11.250 MB.
# Text (code) pages =    5.918 MB.
# Stack = 0 bytes.
# Library pages =   64.098 MB.

# %% [markdown]
# ## Visualize NMOS characteristics

# %% [markdown]
# ## Load NMOS simulation result

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
nmos_w=1e-6
nmos_df = pd.read_csv("nmos_output_dc.txt", delim_whitespace=True, header=0)
nmos_df.columns = ["vgs", "id"]
nmos_df['id'] = nmos_df['id']*-1
nmos_df['gm'] = np.gradient(nmos_df['id'])/np.gradient(nmos_df['vgs']);
nmos_df['gm_id'] = nmos_df['gm']/nmos_df['id']

nmos_ac_df = pd.read_csv("nmos_output_ac.txt", delim_whitespace=True, header=0)
nmos_ac_df.columns = ["frequency", "cgg", "cgg2"]
nmos_cgg = nmos_ac_df["cgg"][0]*-1

nmos_df['f_T'] = nmos_df['gm']/nmos_cgg/2/math.pi
nmos_df['id_w'] = nmos_df['id']/nmos_w
nmos_df['f_T_gm_id'] = nmos_df['f_T']*nmos_df['gm_id']
# Out:
# /tmp/ipykernel_25188/3159818271.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   nmos_df = pd.read_csv("nmos_output_dc.txt", delim_whitespace=True, header=0)
# /tmp/ipykernel_25188/3159818271.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   nmos_ac_df = pd.read_csv("nmos_output_ac.txt", delim_whitespace=True, header=0)

# %% [markdown]
# ## Plot Vgs vs id

# %%
nmos_df.plot(x="vgs", y="id", grid=True,legend=False)
plt.title("id vs Vgs")
plt.ylabel("id [A]")
plt.xlabel("Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot gm vs Vgs

# %%
nmos_df.plot(x="vgs", y="gm", grid=True,legend=False)
plt.title("gm vs Vgs")
plt.ylabel("gm")
plt.xlabel("Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot id/w vs gm/id

# %%
nmos_df.plot(x="gm_id", y="id_w", grid=True,legend=False)
plt.xlim(0, 25)
plt.ylim(0,50e1)
plt.title("id/w vs gm/id")
plt.ylabel("id/w")
plt.xlabel("gm/id")
plt.show()

# %% [markdown]
# ## Calculate W from id and gm

# %%
# Returns interpolated Y for a given X_value using df columns
from scipy import interpolate
f_nmos_gm_id_to_id_w = interpolate.interp1d(nmos_df['gm_id'], nmos_df['id_w'])

#define design parameter
nmos_l = 0.28e-6
nmos_id = 100e-6
nmos_gm = 1000e-6
nmos_gm_id=nmos_gm/nmos_id
nmos_id_w = f_nmos_gm_id_to_id_w(nmos_gm_id)
nmos_w = nmos_id/nmos_id_w
print(f"nmos_id: {nmos_id}")
print(f"nmos_gm: {nmos_gm}")
print(f"nmos_l: {nmos_l}")
print(f"nmos_w: {nmos_w}")
# Out:
# nmos_id: 0.0001
# nmos_gm: 0.001
# nmos_l: 2.8e-07
# nmos_w: 1.3581385998173983e-05

# %% [markdown]
# ## Plot Vgs vs gm/id

# %%
nmos_df.plot(x="vgs", y="gm_id", grid=True,legend=False)
plt.title("gm/id vs Vgs")
plt.ylabel("gm/id")
plt.xlabel("Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot -Vgs vs f_T

# %%
nmos_df.plot(x="vgs", y="f_T", grid=True,legend=False)
plt.title("f_T vs Vgs")
plt.ylabel("f_T [Hz]")
plt.xlabel("Vgs [V]")
plt.show()

# %% [markdown]
# ## Plot f_T*gm/id vs gm/id

# %%
nmos_df.plot(x="gm_id", y="f_T_gm_id", grid=True,legend=False)
plt.title("f_T*gm/id vs gm/id")
plt.ylabel("f_T*gm/id")
plt.xlabel("gm/id")
plt.show()
nmos_max_index=np.argmax(nmos_df['f_T_gm_id'])
nmos_gm_id_on_max_f_T_gm_id = nmos_df['gm_id'][nmos_max_index]
nmos_max_f_T_gm_id = pmos_df['f_T_gm_id'][nmos_max_index]
print('max')
print(f'f_T*gm/id:{nmos_max_f_T_gm_id}')
print(f'gm/id:{nmos_gm_id_on_max_f_T_gm_id}')
# Out:
# max
# f_T*gm/id:22580723548.036427
# gm/id:8.432472702171244

# %% [markdown]
# ## Calculate W and id from gm on Max f_T*gm/id

# %%
#define design parameter
nmos_gm=100e-6
nmos_gm_id=nmos_gm_id_on_max_f_T_gm_id
nmos_id=nmos_gm/nmos_gm_id 
nmos_id_w = f_nmos_gm_id_to_id_w(nmos_gm_id)
nmos_w = nmos_id/nmos_id_w
print(f"nmos_gm: {nmos_gm}")
print(f"nmos_id: {nmos_id}")
print(f"nmos_gm_id: {nmos_gm_id}")
print(f"nmos_l: {nmos_l}")
print(f"nmos_w: {nmos_w}")
# Out:
# nmos_gm: 0.0001
# nmos_id: 1.1858917725787763e-05
# nmos_gm_id: 8.432472702171244
# nmos_l: 2.8e-07
# nmos_w: 1.121306905624644e-06
