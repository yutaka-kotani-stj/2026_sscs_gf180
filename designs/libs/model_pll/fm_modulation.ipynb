# %%
fc = 82.5e6 # Carrier Frequency:Japan Tokyo NHK FM 82.5MHz

delta_f = 75e3 # max frequency deviation 75khz
fm = 15e3 # modulating freqeuncy : max audio frequency 15khz
beta = delta_f/fm # modulation index
bt = 2*fm*(beta+1) # FM bandwidth
am = 1 # Max amplitude of message signal
kf = delta_f/am # 25e3 # frequency sensitivity factor [Hz/V]

# Display the transfer function
print(f"fc:{fc}[Hz]")
print(f"delta_f:{delta_f}[Hz]")
print(f"beta:{beta}")
print(f"bt:{bt}[Hz]")
print(f"kf:{kf}[Hz/V]")
print(f"am:{am}[V]")
# Out:
# fc:82500000.0[Hz]
# delta_f:75000.0[Hz]
# beta:5.0
# bt:180000.0[Hz]
# kf:75000.0[Hz/V]
# am:1[V]
